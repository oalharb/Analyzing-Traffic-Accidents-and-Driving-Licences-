# %% [markdown]
# # Project 1: Driving Licenses, Traffic Accidents and Casualties Analysis

# %% [markdown]
# ## Problem Statment
#
# Craft your problem statement here using the prompt from the README and other sources you find during your investigation.

# %% [markdown]
# ## Executive Summary
# Write an executive summary that summarizes the problem and your key findings.

# %% [markdown]
# #saudi-arabia-traffic-accidents=SATA
# #saudi-arabia-driving-licenses=SADL

# %% [markdown]
# ### Contents:
# - [Datasets Description](#Datasets-Description)
# - [Data Import & Cleaning](#Data-Import-and-Cleaning)
# - [Exploratory Data Analysis](#Exploratory-Data-Analysis)
# - [Data Visualization](#Visualize-the-data)
# - [Descriptive and Inferential Statistics](#Descriptive-and-Inferential-Statistics)
# - [Outside Research](#Outside-Research)
# - [Conclusions and Recommendations](#Conclusions-and-Recommendations)

# %% [markdown]
# **If you combine your problem statement, executive summary, data dictionary, and conclusions/recommendations, you have an amazing README.md file that quickly aligns your audience to the contents of your project.** Don't forget to cite your data sources!

# %% [markdown]
# *All libraries used should be added here, including any Jupyter magic commands*

# %%
#Imports
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns
sns.set(font_scale=1.5)

# %matplotlib inline
#%config InlineBackend.figure_format = 'retina'

# %% [markdown]
# ## Datasets Description
#
# [Driving Licenses](https://datasource.kapsarc.org/explore/dataset/saudi-arabia-driving-licenses-issued-in-the-kingdom-2004-2008/information/?disjunctive.administritive_area&sort=time_period&location=5,24.37495,45.08024&basemap=jawg.streets)
# This dataset contains Saudi Arabia Driving Licenses Issued By Administrative Area for 1993 - 2016. Data from General Authority for Statistics . Follow datasource.kapsarc.org for timely data to advance energy economics research.
#
# [Traffic Accidents and Casualties](https://datasource.kapsarc.org/explore/dataset/saudi-arabia-traffic-accidents-and-casualties-injured-dead-2008/export/?disjunctive.region&disjunctive.indicator&sort=time_period)
# This dataset contains Saudi Arabia Traffic Accidents and Casualties by Region for 2016. Data from General Authority for Statistics. Follow datasource.kapsarc.org for timely data to advance energy economics research.

# %% [markdown]
# ## Data Import and Cleaning

# %% [markdown]
# #### 1. Read In Driving Licenses & Traffic Accidents Data
# Read in the `saudi-arabia-traffic-accidents-2008.csv` and `saudi-arabia-driving-licenses-2004-2008.csv` files and assign them to appropriately named pandas dataframes.

# %%
#Code
SATA=pd.read_csv('../data/saudi-arabia-traffic-accidents-2008.csv',sep=';')
SADL=pd.read_csv('../data/saudi-arabia-driving-licenses-2004-2008.csv',sep=';')

# %% [markdown]
# #### 2. Display data
#
# Print the first 10 rows of each dataframe to your jupyter notebook

# %%
#Code
SATA.head(10)
# Out:
#    Unnamed: 0  Unnamed: 0.1    Year            Region  \
# 0           0             0  (2016)            Makkah
# 1           1             1  (2016)    Eastern Region
# 2           2             2  (2016)            Tabouk
# 3           3             3  (2016)              Hail
# 4           4             4  (2016)              Hail
# 5           5             5  (2016)  Northern Boarder
# 6           6             6  (2017)             Jazan
# 7           7             7  (2017)           Al-Jouf
# 8           8             8  (2017)             Total
# 9           9             9  (2016)  Northern Boarder
#
#                      Indicator   Value                  geo_point_2d
# 0  No. of Casualties - Injured  12383n   21.628962766, 41.2636898334
# 1     No. of Casualties - Dead   1113n  23.2883307307, 50.1478302439
# 2     No. of Casualties - Dead    434n    27.90165499, 37.2598581394
# 3     No. of Casualties - Dead    299n   27.400845724, 41.4406960508
# ...

# %%
SADL.head(10)
# Out:
#    Unnamed: 0    Year Administritive Area Driving Liceses  \
# 0           0  (2012)              Makkah         143954n
# 1           1  (1994)              Makkah          75349n
# 2           2  (1998)              Makkah          86082n
# 3           3  (2004)              Makkah          86636n
# 4           4  (2005)              Makkah          65099n
# 5           5  (2008)              Makkah          77013n
# 6           6  (2014)             Madinah          31447n
# 7           7  (2013)             Madinah          28513n
# 8           8  (2012)             Madinah          14459n
# 9           9  (1994)             Madinah           3767n
#
#                   geo_point_2d
# 0  21.628962766, 41.2636898334
# 1  21.628962766, 41.2636898334
# 2  21.628962766, 41.2636898334
# 3  21.628962766, 41.2636898334
# 4  21.628962766, 41.2636898334
# 5  21.628962766, 41.2636898334
# 6  24.927534539, 39.4918237173
# 7  24.927534539, 39.4918237173
# 8  24.927534539, 39.4918237173
# ...

# %% [markdown]
# #### 3. Briefly describe the data
#
# Take your time looking through the data and briefly describe the data in the markdown cell below. Note things about what the columns might mean, and the general information that is conveyed in the dataframe.

# %% [markdown]
# # Answer:
#
# <p style="color:blue;">There are some unknown variables like 'n' in the Value and Driving Liceses. Also, the year is between parentheses.

# %%
#SATA.info()
SATA.shape
# Out:
# (84, 7)

# %%
#SADL.info()
SADL.shape
# Out:
# (350, 5)

# %% [markdown]
# #### 4a. How complete is the data?
#
# Investigate missing values etc.

# %%
#Code
SATA.isnull().sum()
#(SATA.isnull().sum()/len(SATA)*100).round(1)
# Out:
# Unnamed: 0      0
# Unnamed: 0.1    0
# Year            0
# Region          0
# Indicator       0
# Value           0
# geo_point_2d    6
# dtype: int64

# %%
#SATA.iloc[1:4]

# %%
SADL.isnull().sum()
#SADL.isnull().sum().sort_values(ascending=False)
# Out:
# Unnamed: 0              0
# Year                    0
# Administritive Area     0
# Driving Liceses         0
# geo_point_2d           25
# dtype: int64

# %% [markdown]
# #### 4b. Are there any obvious issues with the observations?
#
# **What is the minimum *possible* value for each dataset? What is the maximum *possible* value?**

# %%
#train, test = train_test_split(SATA, test_size=0.2)
#train, val = train_test_split(train, test_size=0.2)
#print(len(train), 'train examples')
#print(len(val), 'validation examples')
#print(len(test), 'test examples')
#print('Maximum:', SATA.max()) 
#print('Minimum:', SATA.min()) 
#print('Mean:', SATA.mean()) 
#print('Sum:', SATA.sum()) 
#print('Count:', SATA.count())

# %%
#Code
SATA.describe()
# Out:
#        Unnamed: 0  Unnamed: 0.1
# count   84.000000     84.000000
# mean    41.500000     41.500000
# std     24.392622     24.392622
# min      0.000000      0.000000
# 25%     20.750000     20.750000
# 50%     41.500000     41.500000
# 75%     62.250000     62.250000
# max     83.000000     83.000000

# %%
SADL.describe()
# Out:
#        Unnamed: 0
# count  350.000000
# mean   174.500000
# std    101.180532
# min      0.000000
# 25%     87.250000
# 50%    174.500000
# 75%    261.750000
# max    349.000000

# %% [markdown]
# #### 5. What are your data types?
# Display the data types of each feature.

# %%
#code
SATA.dtypes
#SATA.dtypes[SATA.dtypes != 'int64'][SATA.dtypes != 'float64']
# Out:
# Unnamed: 0       int64
# Unnamed: 0.1     int64
# Year            object
# Region          object
# Indicator       object
# Value           object
# geo_point_2d    object
# dtype: object

# %%
SADL.dtypes
# Out:
# Unnamed: 0              int64
# Year                   object
# Administritive Area    object
# Driving Liceses        object
# geo_point_2d           object
# dtype: object

# %% [markdown]
# What did you learn?
# - Do any of them seem odd?
# - Which ones are not as they should be?

# %% [markdown]
# # Answer:
#
# <p style="color:blue;">Some of them are incorrect datatypes like the value and driving_licenses.

# %% [markdown]
# #### 6. Fix incorrect data types
# Based on what you discovered above, use appropriate methods to re-type incorrectly typed data.
# - Define a function that will allow you to convert numerical columns to an appropriate numeric type. Use `map` or `apply` to change these columns in each dataframe.

# %%
#code
SATA['Value'] = SATA['Value'].map(lambda x: x.strip('n'))
SATA['Year'] = SATA['Year'].map(lambda x: x.strip('()'))
SATA['Year'] = SATA['Year'].astype(int)
SATA['Value'] = SATA['Value'].astype(int)

# %%
SADL['Driving Liceses'] = SADL['Driving Liceses'].map(lambda x: x.strip('n'))
SADL['Year'] = SADL['Year'].map(lambda x: x.strip('()'))
SADL['Year'] = SADL['Year'].astype(int)
SADL['Driving Liceses'] = SADL['Driving Liceses'].astype(int)

# %% [markdown]
# - Make new columns `x` and `y` using `geo_point_2d`

# %%
#code
x = []
y = []
for row in SATA['geo_point_2d']:
    try:
        x.append(row.split(',')[0])
        y.append(row.split(',')[1])
    except:
        x.append(np.NaN)
        y.append(np.NaN)
SATA['x'] = x
SATA['y'] = y

# %%
x = []
y = []
for row in SADL['geo_point_2d']:
    try:
        x.append(row.split(',')[0])
        y.append(row.split(',')[1])
    except:
        x.append(np.NaN)
        y.append(np.NaN)
SADL['x'] = x
SADL['y'] = y

# %% [markdown]
# - Fix any individual values preventing other columns from being the appropriate type.

# %%
#code: 
SATA.drop(columns=['Unnamed: 0','Unnamed: 0.1','geo_point_2d'], inplace=True)
SATA['x'] = SATA['x'].astype(float)
SATA['y'] = SATA['y'].astype(float)

# %%
#SATA.head()

# %%
SADL.drop(columns=['Unnamed: 0','geo_point_2d'], inplace=True)
SADL['x'] = SADL['x'].astype(float)
SADL['y'] = SADL['y'].astype(float)

# %% [markdown]
# - Finish your data modifications by making sure the columns are now typed appropriately.

# %%
#code: above ^

# %% [markdown]
# - Display the data types again to confirm they are correct.

# %%
#Code:
SATA.dtypes
# Out:
# Year           int64
# Region        object
# Indicator     object
# Value          int64
# x            float64
# y            float64
# dtype: object

# %%
SADL.dtypes
# Out:
# Year                     int64
# Administritive Area     object
# Driving Liceses          int64
# x                      float64
# y                      float64
# dtype: object

# %% [markdown]
# #### 7. Rename columns
# Change the names of the columns to more expressive names so that you can tell the difference the Driving Licenses  columns and the & Traffic Accidents columns. Your solution should map all column names being changed at once (no repeated singular name-changes). **We will be combining these two datasets, and so you should name columns in an appropriate way**.
#
# **Guidelines**:
# - Column names should be all lowercase (you will thank yourself when you start pushing data to SQL later in the course)
# - Column names should not contain spaces (underscores will suffice--this allows for using the `df.column_name` method to access columns in addition to `df['column_name']`.
# - Column names should be unique and informative (the only feature that we actually share between dataframes is the state).
# - Please also fix any typos you see in the column names.

# %%
print(SATA.columns)
print(SADL.columns)
# Out:
# Index(['Year', 'Region', 'Indicator', 'Value', 'x', 'y'], dtype='object')
# Index(['Year', 'Administritive Area', 'Driving Liceses', 'x', 'y'], dtype='object')

# %%
#code
SATA.columns = [col.lower() for col in SATA.columns]
#print(SATA.columns)
SATA.head(2)
# Out:
#    year          region                    indicator  value          x  \
# 0  2016          Makkah  No. of Casualties - Injured  12383  21.628963
# 1  2016  Eastern Region     No. of Casualties - Dead   1113  23.288331
#
#           y
# 0  41.26369
# 1  50.14783

# %%
SADL.rename(columns={'Administritive Area':'region',
                     'Driving Liceses':'driving_licenses'
                     },inplace=True) 
SADL.columns = [col.lower() for col in SADL.columns]
#print(SADL.columns)
SADL.head(2)
# Out:
#    year  region  driving_licenses          x         y
# 0  2012  Makkah            143954  21.628963  41.26369
# 1  1994  Makkah             75349  21.628963  41.26369

# %% [markdown]
# #### 8. Create a data dictionary
#
# Now that we've fixed our data, and given it appropriate names, let's create a [data dictionary](http://library.ucmerced.edu/node/10249).
#
# A data dictionary provides a quick overview of features/variables/columns, alongside data types and descriptions. The more descriptive you can be, the more useful this document is.
#
# Example of a Fictional Data Dictionary Entry:
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |**county_pop**|*integer*|2010 census|The population of the county (units in thousands, where 2.5 represents 2500 people).|
# |**per_poverty**|*float*|2010 census|The percent of the county over the age of 18 living below the 200% of official US poverty rate (units percent to two decimal places 98.10 means 98.1%)|
#
# [Here's a quick link to a short guide for formatting markdown in Jupyter notebooks](https://jupyter-notebook.readthedocs.io/en/stable/examples/Notebook/Working%20With%20Markdown%20Cells.html).
#
# Provided is the skeleton for formatting a markdown table, with columns headers that will help you create a data dictionary to quickly summarize your data, as well as some examples. **This would be a great thing to copy and paste into your custom README for this project.**

# %% [markdown]
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |year|int|SATA|The year of the accident|,
# |region|object|SATA|The regeion of the accident|,
# |indicator|object|SATA|The number of accident,injured or dead|,
# |value|int|SATA|The number of accident|,
# |x|int|SATA|Latitude|,
# |y|int|SATA|Longitude|,
# |year|int|SADL|The year of the accident|,
# |region|object|SADL|The region of the accident|,
# |driving_licenses|int|SADL|The number of the driving_licenses|,
# |x|int|SADL|Latitude|,
# |y|int|SADL|Longitude|

# %% [markdown]
# #### 9. Drop unnecessary rows
#
# This study concerns accident and license in regions/area. Please do the followings:
# 0. Which rows are not associated with regions?
# 1. Confirm the numbers of all regions add up to total.
# 2. Remove the rows that are not associated with regions

# %%
#code
#groupedSATA = SATA.filter(items=['year','indicator'])  
#groupedSATA = groupedSATA.groupby(['indicator']).count()  
#print(groupedSATA)

# %%
calc_SATA=SATA[SATA['region']!='Total']
calc_SATA.groupby(['year','indicator']).value.sum()
# Out:
# year  indicator
# 2016  No. of Accidents               533380
#       No. of Casualties - Dead         9031
#       No. of Casualties - Injured     38120
# 2017  No. of Accidents               460488
#       No. of Casualties - Dead         7489
#       No. of Casualties - Injured     33199
# Name: value, dtype: int64

# %%
calc_SATA=SATA[SATA['region']=='Total']
calc_SATA.groupby(['year','indicator']).value.sum()
# Out:
# year  indicator
# 2016  No. of Accidents               533380
#       No. of Casualties - Dead         9031
#       No. of Casualties - Injured     38120
# 2017  No. of Accidents               460488
#       No. of Casualties - Dead         7489
#       No. of Casualties - Injured     33199
# Name: value, dtype: int64

# %%
calc_SADL=SADL[SADL['region']!='Total']
calc_SADL.groupby(['year']).driving_licenses.sum()
# Out:
# year
# 1993    294893
# 1994    303520
# 1995    251878
# 1996    237623
# 1997    289296
# 1998    338350
# 1999    332210
# 2000    273238
# 2001    264725
# 2002    282038
# 2003    254858
# 2004    268738
# 2005    251203
# 2006    267508
# 2007    331356
# 2008    330158
# 2009    376275
# 2010    386510
# 2011    400558
# 2012    411204
# 2013    565314
# 2014    625414
# 2015    435439
# 2016    697017
# 2017    928165
# Name: driving_licenses, dtype: int64

# %%
calc_SADL=SADL[SADL['region']=='Total']
calc_SADL.groupby(['year']).driving_licenses.sum()
# Out:
# year
# 1993    294893
# 1994    303520
# 1995    251878
# 1996    237623
# 1997    289296
# 1998    338350
# 1999    332210
# 2000    273238
# 2001    264725
# 2002    282038
# 2003    254858
# 2004    268738
# 2005    251203
# 2006    267508
# 2007    331356
# 2008    330158
# 2009    376275
# 2010    386510
# 2011    400558
# 2012    411204
# 2013    565314
# 2014    625414
# 2015    435439
# 2016    697017
# 2017    928165
# Name: driving_licenses, dtype: int64

# %%
SATA=SATA[SATA.region!='Total']

# %%
SADL=SADL[SADL.region!='Total']

# %% [markdown]
# # <p style="color:red;"> Creating map for the Region

# %%
SATA.region.unique()
# Out:
# array(['Makkah', 'Eastern Region', 'Tabouk', 'Hail', 'Northern Boarder',
#        'Jazan', 'Al-Jouf', 'Al-Baaha', 'Riyadh', 'Madinah', 'Qassim',
#        'Najran', 'Asir'], dtype=object)

# %%
#calc_SADL.region.unique()

# %%
SADL.region=SADL.region.map({'Makkah':'Makkah', 'Madinah':'Madinah', 'Al-Qaseem':'Qassim', 'Eastern':'Eastern Region', 
          'Assir':'Asir', 'Tabouk':'Tabouk',
       'Hail':'Hail', 'Northern Boarder':'Northern Boarder', 'Jazan':'Jazan', 'Najran':'Najran', 'Al-Baha':'Al-Baaha',
       'Al-Jouf':'Al-Jouf', 'Riyadh':'Riyadh'})

# %%
SADL.region.unique()
# Out:
# array(['Makkah', 'Madinah', 'Qassim', 'Eastern Region', 'Asir', 'Tabouk',
#        'Hail', 'Northern Boarder', 'Jazan', 'Najran', 'Al-Baaha',
#        'Al-Jouf', 'Riyadh'], dtype=object)

# %% [markdown]
# #### 10a. Data formats
# Is the License data in long or wide format? How about the Accident data? And why?

# %%
#code
# License data--->SADL is wide because all the features are not repeated 
#Accident data--->SATA is long because it is repeating and it has in the indicator (the number of casualities, dead,injured)

# %% [markdown]
# #### 10b. Changing formats
# Which format would work best for both dataframes? Transform the datasets to the same format before merging in the next task.

# %%
#code
#wide would work best for both dataframes
wide_SATA=pd.pivot_table(SATA,values='value',index=['year','region'],columns='indicator')

# %%
#wide_SATA

# %% [markdown]
# #### 11. Merge dataframes
#
# Join the Driving Licenses & Traffic Accidents dataframes using the **region** and **year** in each dataframe as the key. Assign this to a new variable. Which join should you use to preserve the most data?

# %%
#code
combined=pd.merge(wide_SATA,SADL,how='outer',on=['year','region'])

# %%
combined.rename(columns={'No. of Accidents':'No_of_Accidents',
                     'No. of Casualties - Dead':'No_of_Casualties_Dead',
                         'No. of Casualties - Injured':'No_of_Casualties_Injured'
                     },inplace=True) 
combined.columns = [col.lower() for col in combined.columns]

# %%
#combined

# %% [markdown]
# #### 12. Save your cleaned, merged dataframe
#
# Use a relative path to save out your data as `combined_datasets.csv`.

# %%
#code
combined.to_csv('../data/combined_datasets.csv',index=False)

# %% [markdown]
# ## Exploratory Data Analysis
#
#
# ### Summary Statistics
# Transpose the output of pandas `describe` method to create a quick overview of each numeric feature.

# %%
#Code:
df=combined.describe()
df.transpose()
# Out:
#                           count          mean           std          min  \
# year                      325.0   2005.000000      7.222222  1993.000000
# no_of_accidents            26.0  38225.692308  46493.705035  1414.000000
# no_of_casualties_dead      26.0    635.384615    549.783381   112.000000
# no_of_casualties_injured   26.0   2743.038462   2922.641127   374.000000
# driving_licenses          325.0  28915.347692  47419.058819   915.000000
# x                         325.0     23.810447      4.197987    17.207231
# y                         325.0     42.602789      3.254196    37.259858
#
#                                    25%           50%           75%  \
# year                       1999.000000   2005.000000   2011.000000
# no_of_accidents           10276.250000  16050.500000  30981.250000
# no_of_casualties_dead       241.250000    415.500000    929.250000
# no_of_casualties_injured    923.000000   1618.500000   3784.000000
# ...

# %%
#combined=combined_1.drop(columns=('region'))

# %% [markdown]
# #### Manually calculate standard deviation
#
# $$\sigma = \sqrt{\frac{1}{n}\sum_{i=1}^n(x_i - \mu)^2}$$
#
# - Write a function to calculate standard deviation using the formula above

# %%
combined1= combined.drop(columns=['region'])

# %%
#code
import math  
import sys
# function to calculate the formula of standard deviation
std = {}
def stddv(data):
    for col in data.columns:
        numerator=np.sum((combined1[col] - np.mean(combined1[col]))**2)
        denominator=combined1[col].count() - 1
        std[col]=np.sqrt(numerator/denominator).round(6)
    return (std)

# %%
stddv(combined1)
# Out:
# {'year': 7.222222,
#  'no_of_accidents': 46493.705035,
#  'no_of_casualties_dead': 549.783381,
#  'no_of_casualties_injured': 2922.641127,
#  'driving_licenses': 47419.058819,
#  'x': 4.197987,
#  'y': 3.254196}

# %%
np.std(combined1)
# Out:
# year                            7.211103
# no_of_accidents             45590.828699
# no_of_casualties_dead         539.106959
# no_of_casualties_injured     2865.885411
# driving_licenses            47346.050217
# x                               4.191524
# y                               3.249185
# dtype: float64

# %%
combined1.std()
# Out:
# year                            7.222222
# no_of_accidents             46493.705035
# no_of_casualties_dead         549.783381
# no_of_casualties_injured     2922.641127
# driving_licenses            47419.058819
# x                               4.197987
# y                               3.254196
# dtype: float64

# %% [markdown]
# - Use a **dictionary comprehension** to apply your standard deviation function to each numeric column in the dataframe.  **No loops**
# - Assign the output to variable `sd` as a dictionary where:
#     - Each column name is now a key
#     - That standard deviation of the column is the value
#
# *Example Output :* `{'Driving_Licenses_x': 120, 'Traffic_Accidents_x': 120, ...}`

# %%
#Code:
sd={i:stddv(combined1)[i] for i in['year','no_of_accidents','no_of_casualties_dead','no_of_casualties_injured','driving_licenses']}
sd
# Out:
# {'year': 7.222222,
#  'no_of_accidents': 46493.705035,
#  'no_of_casualties_dead': 549.783381,
#  'no_of_casualties_injured': 2922.641127,
#  'driving_licenses': 47419.058819}

# %% [markdown]
# Do your manually calculated standard deviations match up with the output from pandas `describe`? What about numpy's `std` method?

# %% [markdown]
# # Answer:
#
# <p style="color:blue;">They both match. but nampy is devided by the whole population, and pandas is devided by the sample correction. </p>

# %% [markdown]
# #### Investigate trends in the data
# Using sorting and/or masking (along with the `.head` method to not print our entire dataframe), consider the following questions:
#
# - Which regions have the highest and lowest Driving Licenses based on years (1993 - 2017)
# - Which regions have the highest and lowest mean Traffic Accidents numbers for years (2016 - 2017)
# - What are the regions that have more Driving Licenses issued in each year than the year average?
# - What are the regions that have more Traffic Accidents happened in each year than the year average?
#
# Based on what you've just observed, have you identified any regions that you're especially interested in? **Make a note of these and state *why* you think they're interesting**.
#
# **You should comment on your findings at each step in a markdown cell below your code block**. Make sure you include at least one example of sorting your dataframe by a column, and one example of using boolean filtering (i.e., masking) to select a subset of the dataframe.

# %%
combined.head(10)
# Out:
#    year            region  no_of_accidents  no_of_casualties_dead  \
# 0  2016          Al-Baaha           3618.0                  185.0
# 1  2016           Al-Jouf          10212.0                  245.0
# 2  2016              Asir          32684.0                  983.0
# 3  2016    Eastern Region         101619.0                 1113.0
# 4  2016              Hail          10199.0                  299.0
# 5  2016             Jazan          25873.0                  514.0
# 6  2016           Madinah          14475.0                  822.0
# 7  2016            Makkah         134838.0                 2243.0
# 8  2016            Najran           3235.0                  173.0
# 9  2016  Northern Boarder          13196.0                  193.0
#
#    no_of_casualties_injured  driving_licenses          x          y
# 0                    1227.0              4614  20.148406  41.466548
# 1                     920.0              9371  29.967745  39.557037
# ...

# %% [markdown]
# # <p style="color:red;"> Regions that have highest and lowest Driving Licenses

# %%
#code
combined.nlargest(10,'driving_licenses')[['year','region','driving_licenses']]
# Out:
#      year          region  driving_licenses
# 24   2017          Riyadh            495307
# 11   2016          Riyadh            242851
# 158  2014          Riyadh            194208
# 82   2013          Riyadh            165994
# 85   2015          Makkah            157389
# 110  2011  Eastern Region            151087
# 89   2014          Makkah            149234
# 26   2012          Makkah            143954
# 20   2017          Makkah            142487
# 3    2016  Eastern Region            142307

# %%
combined.nsmallest(10,'driving_licenses')[['year','region','driving_licenses']]
# Out:
#      year            region  driving_licenses
# 205  2015            Tabouk               915
# 177  2007          Al-Baaha               997
# 266  1995  Northern Boarder              1318
# 164  1996  Northern Boarder              1383
# 267  1994  Northern Boarder              1457
# 76   1996          Al-Baaha              1468
# 58   1993  Northern Boarder              1510
# 268  1997  Northern Boarder              1531
# 214  2003  Northern Boarder              1705
# 60   2005  Northern Boarder              1804

# %%
##  the number of highest and lowest regions for driving licenses

# %% [markdown]
# # <p style="color:red;"> Regions that have  highest and lowest Traffic Accidents

# %%
d=combined.groupby(['region']).mean()

# %%
d.nlargest(1,'no_of_accidents')[['no_of_accidents']]
# Out:
#         no_of_accidents
# region
# Makkah         140189.5

# %%
d.nsmallest(1,'no_of_accidents')[['no_of_accidents']]
# Out:
#           no_of_accidents
# region
# Al-Baaha           2516.0

# %%
## ##  the number of highest and lowest regions for traffic accidents

# %% [markdown]
# # <p style="color:red;"> Regions that have more Driving Licenses issued in each year than the year average

# %%
#combined['driving_licenses'].mean()

# %%
h=combined.groupby('year')

# %%
combined['SADL_y_mean']=h['driving_licenses'].transform(np.mean)

# %%
rar=combined[(combined.driving_licenses> combined.SADL_y_mean)][['year','region','driving_licenses','SADL_y_mean']].sort_values('year')
rar.region.unique()
# Out:
# array(['Riyadh', 'Makkah', 'Qassim', 'Eastern Region', 'Asir', 'Hail'],
#       dtype=object)

# %%
rar
# Out:
#      year          region  driving_licenses   SADL_y_mean
# 155  1993          Riyadh            103886  22684.076923
# 183  1993          Makkah             65977  22684.076923
# 301  1993          Qassim             73618  22684.076923
# 105  1994          Qassim             68916  23347.692308
# 27   1994          Makkah             75349  23347.692308
# 157  1994          Riyadh            110545  23347.692308
# 184  1995          Makkah             60356  19375.230769
# 40   1995          Qassim             49690  19375.230769
# 156  1995          Riyadh            101608  19375.230769
# 281  1996          Makkah             46195  18278.692308
# 159  1996          Riyadh            110131  18278.692308
# 41   1996          Qassim             42693  18278.692308
# 248  1997  Eastern Region             58814  22253.538462
# 91   1997          Makkah             76623  22253.538462
# 87   1997          Riyadh             92145  22253.538462
# ...

# %%
## the regions that have more driving licenses issues in every year than the avarage year

# %% [markdown]
# # <p style="color:red;"> Regions that have more Traffic Accidents happened in each year than the year average

# %%
#combined['no_of_accidents'].mean()

# %%
combined['SATA_y_mean']=h['no_of_accidents'].transform(np.mean)

# %%
rar=combined[(combined.no_of_accidents> combined.SATA_y_mean)][['year','region','driving_licenses','SATA_y_mean']].sort_values('year')
rar.region.unique()
# Out:
# array(['Eastern Region', 'Makkah', 'Riyadh'], dtype=object)

# %%
rar
# Out:
#     year          region  driving_licenses   SATA_y_mean
# 3   2016  Eastern Region            142307  41029.230769
# 7   2016          Makkah            136055  41029.230769
# 11  2016          Riyadh            242851  41029.230769
# 16  2017  Eastern Region            126816  35422.153846
# 20  2017          Makkah            142487  35422.153846
# 24  2017          Riyadh            495307  35422.153846

# %%
## the regions that have more traffic accidents in each year than the average year

# %%
combined.drop(columns=['SADL_y_mean','SATA_y_mean'], inplace=True)

# %%
## I have used SADL_y_mean & SATA_y_mean to find the regions that are higher than the average year, 
## then I dropped them because they were added to the dataframe

# %% [markdown]
# ## Visualize the data
#
# There's not a magic bullet recommendation for the right number of plots to understand a given dataset, but visualizing your data is *always* a good idea. Not only does it allow you to quickly convey your findings (even if you have a non-technical audience), it will often reveal trends in your data that escaped you when you were looking only at numbers.
#
# Some recommendations on plotting:
# - Plots have titles
# - Plots have axis labels
# - Plots have appropriate tick labels
# - All text is legible in a plot
# - Plots demonstrate meaningful and valid relationships
# - Plots are interpreted to aid understanding
#
# There is such a thing as too many plots, and there are a *lot* of bad plots. You might make some! (But hopefully not with the guided prompts below).

# %% [markdown]
# #### Use Seaborn's heatmap with pandas `.corr()` to visualize correlations between all numeric features
#
# Heatmaps are generally not appropriate for presentations, and should often be excluded from reports as they can be visually overwhelming. **However**, they can be extremely useful in identify relationships of potential interest (as well as identifying potential collinearity before modeling).
#
# *example*:
# ```python
# sns.heatmap(df.corr())
# ```
#
# Please take time to format your output, adding a title. Look through some of the additional arguments and options. (Axis labels aren't really necessary, as long as the title is informative).

# %%
combined.corr()
# Out:
#                                   year  no_of_accidents  \
# year                      1.000000e+00        -0.061493
# no_of_accidents          -6.149347e-02         1.000000
# no_of_casualties_dead    -1.100110e-01         0.917721
# no_of_casualties_injured -6.604215e-02         0.853038
# driving_licenses          1.954780e-01         0.733692
# x                         2.169974e-18        -0.182375
# y                         2.892627e-17         0.378404
#
#                           no_of_casualties_dead  no_of_casualties_injured  \
# year                                  -0.110011                 -0.066042
# no_of_accidents                        0.917721                  0.853038
# no_of_casualties_dead                  1.000000                  0.930090
# no_of_casualties_injured               0.930090                  1.000000
# driving_licenses                       0.680328                  0.493111
# ...

# %%
plt.figure(figsize=(15,10))
ax=sns.heatmap(combined.corr(), annot=True) # ,vmin = 0, vmax = +1
plt.title('heatmap correlation',fontsize=30)
#ax.set_title('correlation heatmap',fontsize=20)
#plt.xlabel(plt.get_xlabels(),fontsize=14, rotation=15)
ax.set_xticklabels(ax.xaxis.get_ticklabels(), fontsize=14, rotation=50)
plt.show()

# %% [markdown]
# #### Define a custom function to subplot histograms
#
# We should write a function that will take the names of 2+ columns and subplot histograms. While you can use pandas plotting or Seaborn here, matplotlib gives you greater control over all aspects of your plots.
#
# [Helpful Link for Plotting Multiple Figures](https://matplotlib.org/users/pyplot_tutorial.html#working-with-multiple-figures-and-axes)
#
# Here's some starter code:

# %%
def subplot_histograms(dataframe, list_of_columns, list_of_titles, list_of_xlabels):
    nrows = int(np.ceil(len(list_of_columns)/2)) # Makes sure you have enough rows
    fig, ax = plt.subplots(nrows=nrows, ncols=2,figsize=(20,15)) # You'll want to specify your figsize
    ax = ax.ravel() # Ravel turns a matrix into a vector, which is easier to iterate
    for i, column in enumerate(list_of_columns): # Gives us an index value to get into all our lists
        ax[i].hist(dataframe[column]) # feel free to add more settings
        ax[i].set_title(list_of_titles[i])
        ax[i].set_xlabel(list_of_xlabels[i])
        ax[i].grid(False)
        # Set titles, labels, etc here for each subplot

# %% [markdown]
# #### Plot and interpret histograms
# For each of the following:
# - Driving Licenses number
# - Traffic Accidents number
#
# Please plot two additional histograms that will help with your understanding of the data

# %%
# Code
subplot_histograms(combined,['driving_licenses','no_of_accidents','no_of_casualties_dead','no_of_casualties_injured'],
                   ['Driving Licenses number','Traffic Accidents number','Car Accidents Dead','Car Accidents Injured'],
['number of licenses','number of accidents','number of dead','number of injured'])
# Out:
# /Users/omaralharbi/Desktop/anaconda3/lib/python3.7/site-packages/numpy/lib/histograms.py:824: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# /Users/omaralharbi/Desktop/anaconda3/lib/python3.7/site-packages/numpy/lib/histograms.py:825: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %% [markdown]
# #### Plot and interpret scatter plots
#
# For each of the following:
# - Driving Licenses vs. Traffic Accidents for 2017
# - Driving Licenses vs. Traffic Accidents for 2016
# - Driving Licenses for 2016 vs 2017
# - Traffic Accidents for 2016 vs 2017
#
# Plot the two variables against each other using matplotlib or Seaborn
#
# Your plots should show:
# - Two clearly labeled axes
# - A proper title
# - Using colors and symbols that are clear and unmistakable
#
# **Feel free to write a custom function, and subplot if you'd like.** Functions save both time and space.

# %% [markdown]
# # <p style="color:red;"> Driving Licenses vs. Traffic Accidents for 2017

# %%
# Code
plt.scatter(x=combined['driving_licenses'][combined['year']==2017],y=combined['no_of_accidents'][combined['year']==2017])

plt.title('Driving Licenses vs. Traffic Accidents for 2017')
plt.xlabel('driving_licenses')
plt.ylabel('no_of_accidents')
# Out:
# Text(0, 0.5, 'no_of_accidents')

# %% [markdown]
# # <p style="color:red;"> Driving Licenses vs. Traffic Accidents for 2016

# %%
plt.scatter(x=combined['driving_licenses'][combined['year']==2016],y=combined['no_of_accidents'][combined['year']==2016])

plt.title('Driving Licenses vs. Traffic Accidents for 2016')
plt.xlabel('driving_licenses')
plt.ylabel('no_of_accidents')
# Out:
# Text(0, 0.5, 'no_of_accidents')

# %% [markdown]
# # <p style="color:red;"> Driving Licenses for 2016 vs 2017

# %%
plt.scatter(x=combined['driving_licenses'][combined['year']==2016],y=combined['driving_licenses'][combined['year']==2017])

plt.title('Driving Licenses for 2016 vs 2017')
plt.xlabel('driving_licenses 2017')
plt.ylabel('driving_licenses 2016')
# Out:
# Text(0, 0.5, 'driving_licenses 2016')

# %% [markdown]
#  # <p style="color:red;"> Traffic Accidents for 2016 vs 2017

# %%
plt.scatter(x=combined['no_of_accidents'][combined['year']==2017],y=combined['no_of_accidents'][combined['year']==2016])

plt.title('Traffic Accidents for 2016 vs 2017')
plt.xlabel('no_of_accidents 2017')
plt.ylabel('no_of_accidents 2016')
# Out:
# Text(0, 0.5, 'no_of_accidents 2016')

# %% [markdown]
# #### Plot and interpret boxplots
#
# For each numeric variable in the dataframe create a boxplot using Seaborn. Boxplots demonstrate central tendency and spread in variables. In a certain sense, these are somewhat redundant with histograms, but you may be better able to identify clear outliers or differences in IQR, etc.
#
# Multiple values can be plotted to a single boxplot as long as they are of the same relative scale (meaning they have similar min/max values).
#
# Each boxplot should:
# - Only include variables of a similar scale
# - Have clear labels for each variable
# - Have appropriate titles and labels

# %%
fig = plt.figure(figsize=(6,4))
ax = fig.gca()

sns.boxplot('no_of_accidents', data=combined, orient='v',
                fliersize=8, linewidth=1.5, notch=False,
                saturation=0.5, ax=ax)

ax.set_title('No of Accidents boxplot', fontsize=20)

#plt.show()
# Out:
# Text(0.5, 1.0, 'No of Accidents boxplot')

# %%
fig = plt.figure(figsize=(6,4))
ax = fig.gca()


sns.boxplot('no_of_casualties_dead', data=combined, orient='v',
                fliersize=8, linewidth=1.5, notch=False,
                saturation=0.5, ax=ax)

ax.set_title('No of Casualities Dead boxplot', fontsize=20)
# Out:
# Text(0.5, 1.0, 'No of Casualities Dead boxplot')

# %%
fig = plt.figure(figsize=(6,4))
ax = fig.gca()
sns.boxplot('no_of_casualties_injured', data=combined, orient='v',
                fliersize=8, linewidth=1.5, notch=False,
                saturation=0.5, ax=ax)
ax.set_title('No of Casualities Injured boxplot', fontsize=20)
# Out:
# Text(0.5, 1.0, 'No of Casualities Injured boxplot')

# %%
fig = plt.figure(figsize=(6,4))
ax = fig.gca()
sns.boxplot('driving_licenses', data=combined, orient='v',
                fliersize=8, linewidth=1.5, notch=False,
                saturation=0.5, ax=ax)
ax.set_title('Driving Licenses boxplot', fontsize=20)
# Out:
# Text(0.5, 1.0, 'Driving Licenses boxplot')

# %% [markdown]
# #### Feel free to do additional plots below
# *(do research and choose your own chart types & variables)*
#
# Are there any additional trends or relationships you haven't explored? Was there something interesting you saw that you'd like to dive further into? It's likely that there are a few more plots you might want to generate to support your narrative and recommendations that you are building toward. **As always, make sure you're interpreting your plots as you go**.

# %%
#Traffic Accidents for 2016 vs 2017 for all regions
#Driving Licenses for 2016 vs 2017 for all regions
#number of driving licenses issued for all region
#number of traffic of accidents for all region

# %%
ax=sns.catplot(x='region',y="driving_licenses",hue="year",data=combined[combined['year']>=2016].sort_values(by='driving_licenses'),kind='bar',aspect=4)
plt.title('number of driving licenses for all regions 2016 vs 2017',fontsize=30)
# Out:
# Text(0.5, 1, 'number of driving licenses for all regions 2016 vs 2017')

# %%
#ax=sns.catplot(x='region',y="driving_licenses",hue="year",data=combined[combined['year']>=2016],kind='bar',aspect=4)
#plt.title('number of driving licenses 2016 vs 2017',fontsize=30)


ax=sns.catplot(x='region',y='no_of_accidents',hue="year",data=combined[combined['year']>=2016],kind="bar",aspect=4)
plt.title('number of traffic accidents for all regions 2016 vs 2017',fontsize=30)
# Out:
# Text(0.5, 1, 'number of traffic accidents for all regions 2016 vs 2017')

# %%
ax=sns.catplot(x='region',y='driving_licenses',data=combined.sort_values(by='driving_licenses'),kind="bar",ci=None,aspect=4)
plt.title('number of driving licenses issued for all region',fontsize=30)
# Out:
# Text(0.5, 1, 'number of driving licenses issued for all region')

# %%
ax=sns.catplot(x='region',y='no_of_accidents',data=combined[combined['year']>=2016].sort_values(by='no_of_accidents'),kind="bar",ci=None,aspect=4)
plt.title('number of traffic accidents for all region ',fontsize=30)
# Out:
# Text(0.5, 1, 'number of traffic accidents for all region ')

# %% [markdown]
# ## Descriptive and Inferential Statistics

# %%
combined.describe()
# Out:
#               year  no_of_accidents  no_of_casualties_dead  \
# count   325.000000        26.000000              26.000000
# mean   2005.000000     38225.692308             635.384615
# std       7.222222     46493.705035             549.783381
# min    1993.000000      1414.000000             112.000000
# 25%    1999.000000     10276.250000             241.250000
# 50%    2005.000000     16050.500000             415.500000
# 75%    2011.000000     30981.250000             929.250000
# max    2017.000000    145541.000000            2243.000000
#
#        no_of_casualties_injured  driving_licenses           x           y
# count                 26.000000        325.000000  325.000000  325.000000
# mean                2743.038462      28915.347692   23.810447   42.602789
# std                 2922.641127      47419.058819    4.197987    3.254196
# min                  374.000000        915.000000   17.207231   37.259858
# ...

# %% [markdown]
# #### Summarizing Distributions
#
# Above, we used pandas `describe` to provide quick summary statistics of our numeric columns. We also demonstrated many visual relationships.
#
# As data scientists, having a complete understanding of data is imperative prior to modeling.
#
# While we will continue to build our analytic tools, we know that measures of *central tendency*, *spread*, and *shape/skewness* provide a quick summary of distributions.
#
# For each variable in your data, summarize the underlying distributions (in words & statistics)
#  - Be thorough in your verbal description of these distributions.
#  - Be sure to back up these summaries with statistics.

# %% [markdown]
# # Answers:
#
#
# <p style="color:blue;">
# The mode is the number with the highest frequency of the data. The mean is the average of the entire population. However, the mean is influenced by outliers, but the median is not. Standard deviation is a kind of measurement of the variation of the data. This means low std is close to the mean, while high std means the data are skewed like the example of our data.
# <p style="color:blue;">
# The previous figures and timetables show that the mean, std, min, and max number of the numeric values which are the number of accidents, number of casualties (dead & injured), and driving licenses. All of these values are Positively Skewness, which means the tail is on the right side of the distribution, this means mean>median>mode.Also, the number of outliers is affecting the distribution.
# <p style="color:blue;">
# The spread of data is calculated by range, variance, absolute deviations, or IQR. The IQR describes 50% of the data by calculating the difference between the 75th and 25th percentile.
# <p style="color:blue;">
# The variables showed that the average number of accidents was higher than the average of issuing of driving licenses. Meanwhile, the average of casualties injured was four times than casualties dead.

# %% [markdown]
# #### We generally assuming that data we sample from a population will be normally distributed. Do we observe this trend?

# %% [markdown]
# # Answer:
#
# <p style="color:blue;"> No

# %% [markdown]
# Does This Assumption Hold for:
#     - Driving Licenses
#     - Traffic Accidents
# Explain your answers for each distribution and how you think this will affect estimates made from these data.

# %% [markdown]
# # Answer:
# <p style="color:blue;">yes,
# The data rarely is normal distributed because there will be outliers. However, the assumptions of the Driving Licenses and Traffic Accidents are right-skewed, which means these data have outliers that we needed to deal with first. Since the set of data is not big the distribution will be skewed. The higher the data the more normal distribution will be.

# %% [markdown]
# #### Statistical Evaluation of Distributions
#
# **If you feel it's appropriate**, using methods we discussed in class, run hypothesis tests to compare variables of interest in our dataset.

# %%
# Code
from scipy.stats import normaltest

# %%
h_test= combined[['driving_licenses','no_of_accidents','no_of_casualties_dead','no_of_casualties_injured']]

# %%
for h in h_test:
    a,b = normaltest(h_test[h].dropna())
    print('\n'+h+'\n')
    print('zscore = ' , a, 'pvalue = ', b)
    if b > 0.05:
        print('pvalue > 0.05 then it is accepting the null hypothesis')
    else:
        print('pvalue < 0.05 then it is rejecting the null hypothesis')
# Out:
# driving_licenses
#
# zscore =  325.6344141041677 pvalue =  1.9470872744851267e-71
# pvalue < 0.05 then it is rejecting the null hypothesis
#
# no_of_accidents
#
# zscore =  9.604128228241274 pvalue =  0.008212777431565399
# pvalue < 0.05 then it is rejecting the null hypothesis
#
# no_of_casualties_dead
#
# zscore =  10.469759063899353 pvalue =  0.005327466234634826
# pvalue < 0.05 then it is rejecting the null hypothesis
#
# no_of_casualties_injured
#
# zscore =  25.490999951788222 pvalue =  2.9154103508906527e-06
# pvalue < 0.05 then it is rejecting the null hypothesis

# %% [markdown]
# ## Outside Research

# %% [markdown]
# Based upon your observations, choose **three** regions that demonstrate interesting trends in the number of driving licenses and traffic accidents. Spend some time doing outside research on provincial and central policies that might influence these rates, and summarize your findings below. **Feel free to go back and create new plots that highlight these states of interest**. If you bring in any outside tables or charts, make sure you are explicit about having borrowed them. If you quote any text, make sure that it renders as being quoted. (Make sure that you cite your sources -- check with you local instructor for citation preferences).

# %% [markdown]
# # Answer:
# <p style="color:blue;"> Makkah Riyadh Eastern Region
#
# <p style="color:blue;">
# The project we have Concentrating on the relationship between the number of issued driving licenses and the number of traffic accidents.Looking at the most trending cities Makkah, Riyadh, and Eastern. However, the observation of the data showing that there is a relationship between driving licenses and the number of traffic accidents. Nevertheless, Riyadh has a trend of having a lower traffic accident comparing to higher driving licenses in 2017 and 2016.
#
#
# `"Vision 2030 leads to an increase in gasoline prices and the implementation of VAT. The increase in gasoline prices contributes to a short-term decrease in RTAs, injuries, and fatalities by 22.4%, 21.9%, and 14.1%, respectively, while intermediate-term decrease in RTAs and road traffic fatalities is by 72892 and 1842, respectively".`
#
#
# <p style="color:blue;">
# This means the increase in fuel prices will lead to reducing unnecessary trips and driving with care and reasonable speed. Subsequently, traffic accidents will decrease due to the implementation of the 2030 vision. Statistical analyses performed using time series and t-test confirmed the significant effect of fuel prices on reducing RTAs.
#
#
# <p style="color:blue;">
# Results have shown that traffic accidents were continuous increases in the last 3 decades until the increase in fuel prices. When the 2030 vision launched in 2016 there was economic transformation evaluated with traffic accidents, data before and after the increase of the fuel prices was collected. The decrease in traffic accident numbers and casualties (dead & injured) after the increase in fuel prices was recorded. Therefore, the rising of fuel prices and Vision 2030 were to somehow influence traffic accidents especially in big cities like Makkah, Riyadh, and Eastern Region. So, the reasons for the decrease in the number of accidents in 2017 are,
# fuel prices and vision 2030.

# %%
from IPython.display import Image
Image(filename='ft.png')

# this table shows how the fuel prices increased from 2016 to 2017

# %%
Image(filename='ff.png')

# this table shows how the number of accidents affected by the fuel prices.

# %%
Image(filename='ij.jpg')

# %%
Image(filename='ij2.jpg')

# %%
Image(filename='ij4.jpg')

# %%
Image(filename='ij3.jpg')

# %%
Image(filename='ij5.jpg')

# %% [markdown]
# # Reference
# https://www.sciencedirect.com/science/article/pii/S2352646718300553#tbl1

# %% [markdown]
# ## Conclusions and Recommendations

# %% [markdown]
# - Based on your exploration of the data, what are you key takeaways and recommendations?
# - Are there additional data you desire that would better inform your investigations?

# %% [markdown]
# Answer:
#
# <p style="color:blue;">
# It is always better to get more features and data in order to have a clear image of the reasons that cause accidents such as the factors of the accident, the population in the regions, and the weather conditions. All of these causes could be studied and considered for the future to make a good decision. The analysis of these causes and factors can be determined to stop the effect of traffic accidents.
